# %%
import os

# %%
path = "/Users/nikitaprasad/Downloads/Object Detection Project /Project_Object_Detection.v3i.yolov8"
os.chdir(path)

# %%
# !pwd
# Out:
# /Users/nikitaprasad/Downloads/Object Detection Project /Project_Object_Detection.v3i.yolov8

# %%
# Displaying few training images :

import os
from IPython.display import display, Image

# Path to the directory containing the training images
source_folder = '/Users/nikitaprasad/Downloads/Object Detection Project /Project_Object_Detection.v3i.yolov8/train/images'

# Get a list of all image files in the source folder
image_files = [os.path.join(source_folder, f) for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]

# Display the first 10 images
for i in range(10):
    image_path = image_files[i]
    display(Image(filename=image_path))

# %%
# Training model

import os
from ultralytics import YOLO

# Define the path to your project directory
path = "/Users/nikitaprasad/Downloads/Object Detection Project /Project_Object_Detection.v3i.yolov8"

# Change directory to your project path
os.chdir(path)

# Instantiate YOLOv8 object detection model
model = YOLO("yolov8s") 

# Load your dataset and train the model
# Assuming `path` is the directory where your data.yaml file is located
data_config_path = os.path.join(path, "data.yaml")

# Train the model using your dataset
results = model.train(data = data_config_path, epochs = 100, imgsz=300)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       1 # Training model
#       3 import os
# ----> 4 from ultralytics import YOLO
#       6 # Define the path to your project directory
#       7 path = "/Users/nikitaprasad/Downloads/Object Detection Project /Project_Object_Detection.v3i.yolov8"
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
# Display validation images

import os
from IPython.display import display, Image

# Path to the directory containing the validation images
source_folder = '/Users/nikitaprasad/Downloads/Object Detection Project /Project_Object_Detection.v3i.yolov8/valid/images'

# Get a list of all image files in the source folder
image_files = [os.path.join(source_folder, f) for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]

# Display the first 10 images
for i in range(10):
    image_path = image_files[i]
    display(Image(filename=image_path))

# Run the validation command
# !yolo task=detect mode=val model="/Users/nikitaprasad/Downloads/Object Detection Project /Project_Object_Detection.v3i.yolov8/runs/detect/train/weights/best.pt" data=data.yaml source='/Users/kasturijamale/Downloads/Project_Object_Detection.v3i.yolov8/valid/images'
# Out:
# zsh:1: command not found: yolo

# %%
import os
from IPython.display import display, Image

# Path to the directory containing the test images
source_folder = '//Users/nikitaprasad/Downloads/Object Detection Project /Project_Object_Detection.v3i.yolov8/test/images'

# Get a list of all image files in the source folder
image_files = [os.path.join(source_folder, f) for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f)) and not f.startswith('.')]

# Display the first 10 images
for i in range(min(10, len(image_files))):
    image_path = image_files[i]
    display(Image(filename=image_path))

# %%
# !pip install ultralytics

# %%
# Predict the testing images (Task is to detect and the mode is predict)

# !yolo task=detect mode=predict model=/Users/nikitaprasad/Downloads/Object Detection Project /Project_Object_Detection.v3i.yolov8/runs/detect/train/weights/best.pt data=data.yaml source=/Users/kasturijamale/Downloads/Project_Object_Detection.v3i.yolov8/test/images
# Out:
# Traceback (most recent call last):
#   File "/opt/anaconda3/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/ultralytics/cfg/__init__.py", line 904, in entrypoint
#     check_dict_alignment(full_args_dict, {a: ""})
#   File "/opt/anaconda3/lib/python3.12/site-packages/ultralytics/cfg/__init__.py", line 493, in check_dict_alignment
#     raise SyntaxError(string + CLI_HELP_MSG) from e
# SyntaxError: 'Detection' is not a valid YOLO argument. Similar arguments are i.e. ['detect'].
#
#     Arguments received: ['yolo', 'task=detect', 'mode=predict', 'model=/Users/nikitaprasad/Downloads/Object', 'Detection', 'Project', '/Project_Object_Detection.v3i.yolov8/runs/detect/train/weights/best.pt', 'data=data.yaml', 'source=/Users/kasturijamale/Downloads/Project_Object_Detection.v3i.yolov8/test/images']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
# ...

# %%
import sys
# !{sys.executable} -m pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.3.86-py3-none-any.whl.metadata (35 kB)
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata (20 kB)
# ...
#   Using cached torch-2.6.0-cp312-none-macosx_11_0_arm64.whl.metadata (28 kB)
# ...
#   Using cached torchvision-0.21.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.1 kB)
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 2.2 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
# Using cached ultralytics-8.3.86-py3-none-any.whl (922 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 13.2 MB/s eta 0:00:0000:0100:01
# ...

# %%
from ultralytics import YOLO
import cv2
import math

# Start the webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Load model
model = YOLO("/Users/nikitaprasad/Downloads/Object Detection Project /Project_Object_Detection.v3i.yolov8/runs/detect/train/weights/best.pt")

# Object classes
classNames = ["Bag", "Footwear", "Teddy"]

while True:
    success, img = cap.read()

    if not success or img is None:
        print("Error: Failed to capture frame.")
        break

    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes

        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])

            # Draw bounding box
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 0, 255), 3)

            # Confidence score
            confidence = math.ceil((box.conf[0] * 100)) / 100
            print("Confidence --->", confidence)

            # Class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # Display text
            cv2.putText(img, classNames[cls], (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

    cv2.imshow('Webcam', img)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 256x320 (no detections), 49.7ms
# Speed: 1.4ms preprocess, 49.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 Bag, 1 Footwear, 38.6ms
# Confidence ---> 0.91
# Class name --> Bag
# Confidence ---> 0.32
# Class name --> Footwear
# Speed: 0.7ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 Bag, 40.3ms
# Confidence ---> 0.91
# Class name --> Bag
# Speed: 0.7ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 Bag, 43.5ms
# Confidence ---> 0.9
# Class name --> Bag
# Speed: 0.6ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 Bag, 41.1ms
# Confidence ---> 0.87
# Class name --> Bag
# Speed: 0.5ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 1 Bag, 54.9ms
# Confidence ---> 0.88
# Class name --> Bag
# ...
